# %%
import pandas as pd
import json
from pandas import json_normalize
import numpy as np

# %%
deck_statistic = pd.read_csv('덱 통계량과 추천 조합(태블로용 최종본).csv')

# '이타심'에서 '자야' 컬럼까지를 드랍
deck_statistic.drop(columns=deck_statistic.loc[:, '이타심':'자야'], inplace=True)

# 드랍 확인
deck_statistic.head()
# Out:
#      deck_name  game_length  placement  last_round  level  deck_count  \
# 0  4비전마법사 4파수꾼      2211.85       4.35       33.11   8.75        55.0
# 1      4용군주 밸류      2215.27       3.81       33.97   9.14       570.0
# 2    5먹그림자 카이사      2220.87       4.53       33.02   8.49        49.0
# 3        6거대괴수      2288.67       4.82       31.87   8.16        38.0
# 4         6기원자      2205.23       4.35       32.91   8.72       163.0
#
#    deck_winrate  deck_pickrate  deck_top4rate champion1 champion2 champion3  \
# 0     10.909091       0.592162      49.090909        아리         쉔       아무무
# 1     21.228070       6.136951      60.526316        잔나      다이애나       리 신
# 2     12.244898       0.527562      53.061224        잭스      아트록스      볼리베어
# 3      7.894737       0.409130      52.631579      말파이트       초가스         쉔
# 4      9.202454       1.754953      53.374233       코그모        잔나        알룬
#
#   champion4 champion5 champion6 champion7 champion8 champion9
# ...

# %%
# 핵심 챔피언 1,2,3 컬럼 생성

deck_statistic['핵심 챔피언1'] = None
deck_statistic['핵심 챔피언2'] = None
deck_statistic['핵심 챔피언3'] = None

# 대체 챔피언 필요 1,2,3 컬럼 생성

deck_statistic['대체 챔피언 필요1'] = None
deck_statistic['대체 챔피언 필요2'] = None
deck_statistic['대체 챔피언 필요3'] = None

# 덱 관련 안내문 컬럼 생성

deck_statistic['안내문'] = None

# 생성 확인
deck_statistic.head()
# Out:
#      deck_name  game_length  placement  last_round  level  deck_count  \
# 0  4비전마법사 4파수꾼      2211.85       4.35       33.11   8.75        55.0
# 1      4용군주 밸류      2215.27       3.81       33.97   9.14       570.0
# 2    5먹그림자 카이사      2220.87       4.53       33.02   8.49        49.0
# 3        6거대괴수      2288.67       4.82       31.87   8.16        38.0
# 4         6기원자      2205.23       4.35       32.91   8.72       163.0
#
#    deck_winrate  deck_pickrate  deck_top4rate champion1  ... champion7  \
# 0     10.909091       0.592162      49.090909        아리  ...      리산드라
# 1     21.228070       6.136951      60.526316        잔나  ...        오공
# 2     12.244898       0.527562      53.061224        잭스  ...       우디르
# 3      7.894737       0.409130      52.631579      말파이트  ...      모르가나
# 4      9.202454       1.754953      53.374233       코그모  ...        애니
#
#   champion8 champion9 핵심 챔피언1 핵심 챔피언2 핵심 챔피언3 대체 챔피언 필요1 대체 챔피언 필요2  \
# ...

# %%
deck_statistic['deck_name'].unique()
# Out:
# array(['4비전마법사 4파수꾼', '4용군주 밸류', '5먹그림자 카이사', '6거대괴수', '6기원자', '6난동꾼',
#        '6비전 마법사', '6암영 4사신 요네', '6혼령 리롤', '7신화 릴리아', '7이야기꾼', '7필연',
#        '8결투가', '나르 세나 리롤', '난동꾼 카이사', '리롤 결투가', '분류 불가', '숲지기 킨드레드 리롤',
#        '신화 바드 리롤', '신화 코그모 리롤', '아펠 아무무 리롤', '용군주 흐웨이 밸류 시도',
#        '용군주 흐웨이 밸류 완성', '천계', '현자 모르가나'], dtype=object)

# %%
deck_statistic[deck_statistic['deck_name']=='4비전마법사 4파수꾼'].loc[:, 'champion1':'champion9']
# Out:
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 0        아리         쉔       아무무      일라오이      노틸러스       신드라      리산드라
#
#   champion8 champion9
# 0        세트       NaN

# %%
## 4비전 4파수꾼 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '아무무', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '일라오이', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '신드라', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '신드라', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '리산드라', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', '세트', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '4비전마법사 4파수꾼', 
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='4용군주 밸류'].loc[:, 'champion1':'champion9'])

#deck_statistic[deck_statistic['deck_name']=='4비전마법사 4파수꾼']
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 1        잔나      다이애나       리 신        오른        라칸       아지르        오공
#
#   champion8 champion9
# 1       우디르       흐웨이

# %%
## 4용군주 밸류 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '오공', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '우디르', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '흐웨이', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '오공', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', '흐웨이', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '4용군주 밸류', 
                                  '난이도가 높은 9레벨 완성덱입니다. 덱 밸류의 핵심이 되는 5코스트 챔피언을 찾아서 넣기 위하여 빠르게 9레벨을 달성할 필요가 있습니다. 따라서 체력 관리에 집중하시고, 돈을 아껴 최대한 경험치를 구매하세요', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='5먹그림자 카이사'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 2        잭스      아트록스      볼리베어      일라오이        오른       카이사       우디르
#
#   champion8 champion9
# 2        자야       NaN

# %%
## 5먹그림자 카이사 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '카이사', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '우디르', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '자야', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '카이사', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', '자야', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '5먹그림자 카이사', 
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6거대괴수'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 3      말파이트       초가스         쉔        요릭       쓰레쉬        오른      모르가나
#
#   champion8 champion9
# 3        오공       NaN

# %%
## 6거대괴수 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '쉔', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '요릭', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '모르가나', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '오른', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '모르가나', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6거대괴수', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6거대괴수', 
                                  '6레벨 리롤 덱입니다. 6레벨 달성 후, 덱의 핵심 2코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6기원자'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 4       코그모        잔나        알룬      탐 켄치       릴리아      사일러스        애니
#
#   champion8 champion9
# 4       아지르       NaN

# %%
## 6기원자 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6기원자', '릴리아', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6기원자', '애니', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6기원자', '아지르', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6기원자', '릴리아', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6기원자', '애니', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6기원자', '아지르', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6기원자', 
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6난동꾼'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 5       렉사이       코부코        리븐       자이라       소라카      탐 켄치       갈리오
#
#   champion8 champion9
# 5      사일러스       NaN

# %%
## 6난동꾼 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '리븐', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '자이라', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '사일러스', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '탐 켄치', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '갈리오', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6난동꾼', '사일러스', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6난동꾼', 
                                  '6레벨 리롤 덱입니다. 6레벨 달성 후, 덱의 핵심 2코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6비전 마법사'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 6        아리        니코        럭스       쓰레쉬      일라오이       신드라      리산드라
#
#   champion8 champion9
# 6        세트       NaN

# %%
## 6비전 마법사 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '럭스', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '일라오이', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '신드라', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '신드라', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '리산드라', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', '세트', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6비전 마법사', 
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6암영 4사신 요네'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 7      다리우스       카직스        요릭      킨드레드        알룬        요네      사일러스
#
#   champion8 champion9
# 7        케인        세트

# %%
## 6암영 4사신 요네 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '알룬', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '요네', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '케인', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '사일러스', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '케인', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', '세트', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6암영 4사신 요네', 
                                  '7레벨 리롤 덱입니다. 7레벨 달성 후, 덱의 핵심 3코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='6혼령 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 8        잭스      케이틀린        세나         쉔      아트록스      일라오이      모르가나
#
#   champion8 champion9
# 8        케인       NaN

# %%
## 6혼령 리롤 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '세나', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '쉔', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '일라오이', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '일라오이', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '모르가나', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤', '케인', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '6혼령 리롤',
                                  '6레벨 리롤 덱입니다. 6레벨 달성 후, 덱의 핵심 2코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])

# 릴리아덱 오류 수정
deck_statistic['champion7']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '릴리아', deck_statistic['champion7'])
deck_statistic['champion1']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '애니', deck_statistic['champion1'])

print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='7신화 릴리아'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#   champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 9        애니       코그모        니코        바드      탐 켄치      노틸러스       릴리아
#
#   champion8 champion9
# 9       흐웨이       NaN

# %%
## 7신화 릴리아 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '애니', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '릴리아', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '노틸러스', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '릴리아', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '애니', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아', '흐웨이', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '7신화 릴리아',
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='7이야기꾼'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 10        가렌       시비르        리븐       자이라        조이       갈리오       리 신
#
#    champion8 champion9
# 10      이렐리아       NaN

# %%
## 7이야기꾼 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '가렌', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '시비르', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '이렐리아', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '갈리오', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '리 신', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '7이야기꾼', '이렐리아', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '7이야기꾼',
                                  '1코스트 리롤 덱입니다. 덱의 핵심 1코스트 챔피언이 모두 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='7필연'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 11        아리       야스오      킨드레드       쓰레쉬     아펠리오스       신드라       우디르
#
#    champion8 champion9
# 11        세트       NaN

# %%
## 7필연 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '7필연', '아리', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '7필연', '야스오', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '7필연', '쓰레쉬', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '7필연', '신드라', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '7필연', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '7필연', '세트', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '7필연',
                                  '1코스트 리롤 덱입니다. 덱의 핵심 1코스트 챔피언이 모두 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='8결투가'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 12      다리우스       야스오       키아나      다이애나     트리스타나      볼리베어       리 신
#
#    champion8 champion9
# 12      이렐리아       NaN

# %%
## 8결투가 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '8결투가', '볼리베어', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '8결투가', '트리스타나', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '8결투가', '리 신', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '8결투가', '볼리베어', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '8결투가', '리 신', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '8결투가', '이렐리아', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '8결투가',
                                  '8결투가는 결투가 상징이 없다면 완성할 수 없는 시너지입니다. 반드시 결투가 상징을 보유하고 있을 때만 이 덱을 시도하시기 바랍니다. 상징이 없다면 덱에서 조합이 유사한 리롤 결투가를 선택하고 해당 덱의 가이드를 참고해주시기 바랍니다. 주의사항을 제외하면 일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='나르 세나 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 13       렉사이        잭스      케이틀린        나르        세나      아트록스      일라오이
#
#    champion8 champion9
# 13      노틸러스       NaN

# %%
## 나르 세나 리롤 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '나르', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '세나', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '아트록스', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '잭스', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '일라오이', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤', '노틸러스', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '나르 세나 리롤',
                                  '6레벨 리롤 덱입니다. 6레벨 달성 후, 덱의 핵심 2코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='난동꾼 카이사'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 14       시비르        리븐      아트록스        티모       갈리오      사일러스       카이사
#
#    champion8 champion9
# 14       우디르        자야

# %%
## 난동꾼 카이사 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '티모', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '카이사', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '갈리오', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '카이사', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사', '자야', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '난동꾼 카이사',
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='리롤 결투가'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 15       야스오       키아나      다이애나      볼리베어     트리스타나       리 신        오공
#
#    champion8 champion9
# 15      이렐리아       NaN

# %%
## 리롤 결투가 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '볼리베어', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '트리스타나', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '리 신', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '리 신', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '오공', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '리롤 결투가', '이렐리아', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '리롤 결투가',
                                  '7레벨 리롤 덱입니다. 7레벨 달성 후, 덱의 핵심 3코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='숲지기 킨드레드 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 17       렉사이       카직스        나르      킨드레드        요네      사일러스        오른
#
#    champion8 champion9
# 17        케인       NaN

# %%
## 숲지기 킨드레드 리롤 컬럼 채워넣기 


deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '나르', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '킨드레드', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '요네', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '사일러스', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '오른', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤', '케인', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '숲지기 킨드레드 리롤',
                                  '6레벨 리롤 덱입니다. 6레벨 달성 후, 덱의 핵심 2코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='신화 바드 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 18       시비르        니코        리븐        바드       소라카        조이      탐 켄치
#
#    champion8 champion9
# 18        라칸        오공

# %%
## 신화 바드 리롤 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '바드', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '탐 켄치', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '소라카', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '조이', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '라칸', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '신화 바드 리롤',
                                  '7레벨 리롤 덱입니다. 7레벨 달성 후, 덱의 핵심 3코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='신화 코그모 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 19      말파이트       초가스      케이틀린       코그모        니코      일라오이      노틸러스
#
#    champion8 champion9
# 19       릴리아       NaN

# %%
## 신화 코그모 리롤 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '초가스', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '케이틀린', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '코그모', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '일라오이', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '노틸러스', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤', '릴리아', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '신화 코그모 리롤',
                                  '1코스트 리롤 덱입니다. 덱의 핵심 1코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='아펠 아무무 리롤'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 20         쉔      킨드레드       아무무      일라오이     아펠리오스       쓰레쉬       신드라
#
#    champion8 champion9
# 20        애쉬        세트

# %%
## 아펠 아무무 리롤 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '쓰레쉬', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '아무무', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '아펠리오스', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '신드라', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '애쉬', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤', '세트', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '아펠 아무무 리롤',
                                  '7레벨 리롤 덱입니다. 7레벨 달성 후, 덱의 핵심 3코스트 챔피언이 3성이 될 때까지 경험치를 구매하지 않고 리롤에 집중합니다. 모두 3성이 되었다면 레벨업하여 덱을 완성시킵니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='용군주 흐웨이 밸류 완성'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 22        잔나      다이애나       소라카        오른       아지르       흐웨이        라칸
#
#    champion8 champion9
# 22       우디르        오공

# %%
## 용군주 흐웨이 밸류 완성 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '흐웨이', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '우디르', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '오공', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '아지르', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 완성',
                                  '난이도가 높은 9레벨 완성덱입니다. 덱 밸류의 핵심이 되는 5코스트 챔피언을 찾아서 넣기 위하여 빠르게 9레벨을 달성할 필요가 있습니다. 따라서 체력 관리에 집중하시고, 돈을 아껴 최대한 경험치를 구매하세요', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='용군주 흐웨이 밸류 시도'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 21        잔나      다이애나       소라카        오른       아지르       흐웨이        라칸
#
#    champion8 champion9
# 21       우디르        오공

# %%
## 용군주 흐웨이 밸류 시도 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '흐웨이', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '우디르', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '오공', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '아지르', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '우디르', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '용군주 흐웨이 밸류 시도',
                                  '난이도가 높은 9레벨 완성덱입니다. 덱 밸류의 핵심이 되는 5코스트 챔피언을 찾아서 넣기 위하여 빠르게 9레벨을 달성할 필요가 있습니다. 따라서 체력 관리에 집중하시고, 돈을 아껴 최대한 경험치를 구매하세요', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='천계'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 23      말파이트       카직스       키아나        니코      다이애나       소라카       리 신
#
#    champion8 champion9
# 23        라칸        오공

# %%
## 천계 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '천계', '니코', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '천계', '소라카', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '천계', '오공', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '천계', '리 신', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '천계', '라칸', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '천계', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '천계',
                                  '천계 덱은 지원아이템인 즈롯에서 나온 소환물을 천계 시너지로 강화시키는 것이 주가 되는 독특한 덱입니다. 반드시 증강체 등을 통하여 많은 지원 아이템을 획득하는 것이 가능한 경우에만 해당 덱을 시도해주시기 바랍니다. 불가능하다면 다른 덱의 가이드를 선택하여 열람하시기 바랍니다. 주의사항을 제외하면 일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())

print(deck_statistic[deck_statistic['deck_name']=='현자 모르가나'].loc[:, 'champion1':'champion9'])
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']
#    champion1 champion2 champion3 champion4 champion5 champion6 champion7  \
# 24        리븐       자이라      다이애나       소라카       갈리오      모르가나        케인
#
#    champion8 champion9
# 24        오공       NaN

# %%
## 현자 모르가나 컬럼 채워넣기 

deck_statistic['핵심 챔피언1']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '모르가나', deck_statistic['핵심 챔피언1'])
deck_statistic['핵심 챔피언2']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '케인', deck_statistic['핵심 챔피언2'])
deck_statistic['핵심 챔피언3']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '오공', deck_statistic['핵심 챔피언3'])

deck_statistic['대체 챔피언 필요1']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '모르가나', deck_statistic['대체 챔피언 필요1'])
deck_statistic['대체 챔피언 필요2']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '케인', deck_statistic['대체 챔피언 필요2'])
deck_statistic['대체 챔피언 필요3']  = np.where(deck_statistic['deck_name'] == '현자 모르가나', '오공', deck_statistic['대체 챔피언 필요3'])

deck_statistic['안내문']  = np.where(deck_statistic['deck_name'] == '현자 모르가나',
                                  '일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 체력 관리를 한 뒤, 8렙에 도달하면 주요 4코스트 및 5코스트 챔피언을 2성까지 달성하여 덱을 완성해줍니다', 
                                  deck_statistic['안내문'])


print(deck_statistic['deck_name'].unique())
# Out:
# ['4비전마법사 4파수꾼' '4용군주 밸류' '5먹그림자 카이사' '6거대괴수' '6기원자' '6난동꾼' '6비전 마법사'
#  '6암영 4사신 요네' '6혼령 리롤' '7신화 릴리아' '7이야기꾼' '7필연' '8결투가' '나르 세나 리롤' '난동꾼 카이사'
#  '리롤 결투가' '분류 불가' '숲지기 킨드레드 리롤' '신화 바드 리롤' '신화 코그모 리롤' '아펠 아무무 리롤'
#  '용군주 흐웨이 밸류 시도' '용군주 흐웨이 밸류 완성' '천계' '현자 모르가나']

# %%
deck_statistic[deck_statistic['deck_name']=='현자 모르가나']
# Out:
#    deck_name  game_length  placement  last_round  level  deck_count  \
# 24   현자 모르가나      2206.61       5.12        31.4   8.64       400.0
#
#     deck_winrate  deck_pickrate  deck_top4rate champion1  ... champion7  \
# 24          5.75       4.306632           35.0        리븐  ...        케인
#
#    champion8 champion9 핵심 챔피언1 핵심 챔피언2 핵심 챔피언3 대체 챔피언 필요1 대체 챔피언 필요2  \
# 24        오공       NaN    모르가나      케인      오공       모르가나         케인
#
#    대체 챔피언 필요3                                                안내문
# 24         오공  일반적인 템포를 지닌 8렙 완성덱입니다. 8렙까지 일반적인 빌드업을 통해 적절하게 ...
#
# [1 rows x 25 columns]

# %%
deck_statistic.to_csv('덱추천조합, 통계량, 핵심기물, 대체필요기물, 안내문.csv', index=False)

# %%
deck_statistic
# Out:
#         deck_name  game_length  placement  last_round  level  deck_count  \
# 0     4비전마법사 4파수꾼      2211.85       4.35       33.11   8.75        55.0
# 1         4용군주 밸류      2215.27       3.81       33.97   9.14       570.0
# 2       5먹그림자 카이사      2220.87       4.53       33.02   8.49        49.0
# 3           6거대괴수      2288.67       4.82       31.87   8.16        38.0
# 4            6기원자      2205.23       4.35       32.91   8.72       163.0
# 5            6난동꾼      2221.34       5.26       31.41   8.54        74.0
# 6         6비전 마법사      2212.69       4.88       31.78   8.38       108.0
# 7      6암영 4사신 요네      2226.50       3.43       35.15   8.47        91.0
# 8          6혼령 리롤      2194.64       3.67       34.29   8.27       363.0
# 9         7신화 릴리아      2238.06       3.35       35.04   8.87       175.0
# 10          7이야기꾼      2206.71       4.22       33.23   8.82       326.0
# 11            7필연      2213.60       3.82       33.84   8.63       384.0
# ...
